# %%
# !pip install elasticsearch
# Out:
# Collecting elasticsearch
#   Obtaining dependency information for elasticsearch from https://files.pythonhosted.org/packages/6b/d7/b7a45c7ed73a0e4ac6a2d2430e55c2f735d9885a6e3b0319e30285288dba/elasticsearch-8.13.0-py3-none-any.whl.metadata
#   Downloading elasticsearch-8.13.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting elastic-transport<9,>=8.13 (from elasticsearch)
#   Obtaining dependency information for elastic-transport<9,>=8.13 from https://files.pythonhosted.org/packages/aa/2f/7606c450a4ba07cd8ba818845ea2dca880a76fad5536f6d038289713a619/elastic_transport-8.13.0-py3-none-any.whl.metadata
#   Downloading elastic_transport-8.13.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: urllib3<3,>=1.26.2 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2.0.6)
# Requirement already satisfied: certifi in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2023.7.22)
# Downloading elasticsearch-8.13.0-py3-none-any.whl (451 kB)
#    ---------------------------------------- 0.0/451.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/451.0 kB ? eta -:--:--
#     --------------------------------------- 10.2/451.0 kB ? eta -:--:--
#    --- ----------------------------------- 41.0/451.0 kB 393.8 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/451.0 kB 751.6 kB/s eta 0:00:01
#    ----------------------- ---------------- 266.2/451.0 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 451.0/451.0 kB 1.9 MB/s eta 0:00:00
# Downloading elastic_transport-8.13.0-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.3 kB ? eta -:--:--
#    ---------------------------------------- 64.3/64.3 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: elastic-transport, elasticsearch
# Successfully installed elastic-transport-8.13.0 elasticsearch-8.13.0

# %%
es_host = "dados-pcdas.icict.fiocruz.br"
es_port = "443"
es_transport_schema  = "https"
es_user = "julianamrosa"
es_pwd = "senhaparaoMicael00!"

# %%
from elasticsearch import Elasticsearch, helpers

# %%
# Conexao ao ES
es = Elasticsearch(es_transport_schema+'://'+es_user+':'+es_pwd+'@'+es_host+':'+es_port+'/')

# %%
es
# Out:
# <Elasticsearch(['https://dados-pcdas.icict.fiocruz.br:443'])>

# %%
#es.info()

# %%
from ftplib import FTP
import os


ftp = FTP(host='ftp.datasus.gov.br')
ftp.login()
download_path = '/dissemin/publicos'

# %%
from ftplib import FTP
import os


ftp = FTP(host='ftp.datasus.gov.br')
ftp.login()
download_path = '/dissemin/publicos'

info = sorted([
    'SIHSUS - Arquivos dissemináveis para tabulação do Sistema de Informações Hospitalares do SUS',
    'SIASUS - Arquivos dissemináveis para tabulação do Sistema de Informações Ambulatoriais do SUS',
    'SIM - Arquivos dissemináveis para tabulação do Sistema de informações de Mortalidade',
    'CIH - Arquivos dissemináveis para tabulação do Sistema de Comunicação de Informação Hospitalar',
    'CIHA - Arquivos dissemináveis para tabulação do Sistema de Comunicação de Informação Hospitalar e Ambulatorial',
    'SINASC - Arquivos dissemináveis para tabulação do Sistema de informação de Nascidos Vivos',
    'SISPRENATAL - Arquivos dissemináveis para tabulação do Sistema de Monitoramento e Avaliação do Pré-Natal, Parto, Puerpério e Criança',
    'SISAB - Arquivos dissemináveis para tabulação do Sistema de Informação em Saúde para a Atenção Básica.',
    'SINAN - Arquivos dissemináveis para tabulação do Sistema de agravos de notificação compulsória.'
])


for i in info:
    print(str(info.index(i)) + ') ' + str(i))


pasta = int(input('\nDigite o número da pasta que quer acessar: \n'))


if pasta == 8:
    folder = download_path + '/CMD'
else:
    folder = download_path + '/' + info[pasta].split(' -')[0]
ftp.cwd(folder)


dir_create = info[pasta].split(' -')[0]

actual_path = os.path.dirname(os.path.abspath(__file__))


if (info[pasta].split(' -')[0] == 'CIH') | (info[pasta].split(' -')[0] == 'CIHA') | (
        info[pasta].split(' -')[0] == 'SIHSUS') | (info[pasta].split(' -')[0] == 'SISPRENATAL'):
    for i in ftp.nlst():
        print(str(ftp.nlst().index(i)) + ') ' + str(i))
    choice = int(input("\nDigite o número da pasta que deseja acessar: \n"))

    new_dir = str(ftp.nlst()[choice]) + '_' + str(dir_create)
    if not os.path.exists(actual_path + '/' + str(new_dir)):
        os.mkdir(actual_path + '/' + str(new_dir))

    try:
        ftp.cwd(folder + '/' + ftp.nlst()[choice] + '/' + 'Dados')
    except BaseException:
        try:
            ftp.cwd(folder + '/' + ftp.nlst()[choice] + '/' + 'CSV')
        except BaseException:
            ftp.cwd(folder + '/' + ftp.nlst()[choice])

    for item in ftp.nlst():
        handle = open(actual_path + '/' + new_dir + '/' + str(item), 'wb')

    print('\nDownload em andamento.')

    ftp.retrbinary('RETR ' + ftp.nlst()[0], handle.write)


elif info[pasta].split(' -')[0] == 'SISAB':
    ftp.cwd(folder + '/DadosSISAB')

    new_dir = 'Dados_' + str(dir_create)
    if not os.path.exists(actual_path + '/' + str(new_dir)):
        os.mkdir(actual_path + '/' + str(new_dir))

    for item in ftp.nlst():
        handle = open(actual_path + '/' + new_dir + '/' + str(item), 'wb')

    print('\nDownload em andamento.')
# Out:
# 0) CIH - Arquivos dissemináveis para tabulação do Sistema de Comunicação de Informação Hospitalar
# 1) CIHA - Arquivos dissemináveis para tabulação do Sistema de Comunicação de Informação Hospitalar e Ambulatorial
# 2) SIASUS - Arquivos dissemináveis para tabulação do Sistema de Informações Ambulatoriais do SUS
# 3) SIHSUS - Arquivos dissemináveis para tabulação do Sistema de Informações Hospitalares do SUS
# 4) SIM - Arquivos dissemináveis para tabulação do Sistema de informações de Mortalidade
# 5) SINAN - Arquivos dissemináveis para tabulação do Sistema de agravos de notificação compulsória.
# 6) SINASC - Arquivos dissemináveis para tabulação do Sistema de informação de Nascidos Vivos
# 7) SISAB - Arquivos dissemináveis para tabulação do Sistema de Informação em Saúde para a Atenção Básica.
# 8) SISPRENATAL - Arquivos dissemináveis para tabulação do Sistema de Monitoramento e Avaliação do Pré-Natal, Parto, Puerpério e Criança
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 38
#      33 ftp.cwd(folder)
#      36 dir_create = info[pasta].split(' -')[0]
# ---> 38 actual_path = os.path.dirname(os.path.abspath(__file__))
#      41 if (info[pasta].split(' -')[0] == 'CIH') | (info[pasta].split(' -')[0] == 'CIHA') | (
#      42         info[pasta].split(' -')[0] == 'SIHSUS') | (info[pasta].split(' -')[0] == 'SISPRENATAL'):
#      43     for i in ftp.nlst():
#
# NameError: name '__file__' is not defined

# %%
# !pip install pysus
# Out:
# Collecting pysus
#   Downloading PySUS-0.6.0.tar.gz (3.3 MB)
#      ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.3 MB 217.9 kB/s eta 0:00:15
#      - -------------------------------------- 0.1/3.3 MB 401.6 kB/s eta 0:00:08
#      -- ------------------------------------- 0.2/3.3 MB 784.3 kB/s eta 0:00:04
#      --- ------------------------------------ 0.3/3.3 MB 948.8 kB/s eta 0:00:04
#      ---- ----------------------------------- 0.4/3.3 MB 1.2 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.4/3.3 MB 1.1 MB/s eta 0:00:03
#      ------ --------------------------------- 0.6/3.3 MB 1.2 MB/s eta 0:00:03
#      ------- -------------------------------- 0.6/3.3 MB 1.2 MB/s eta 0:00:03
#      -------- ------------------------------- 0.7/3.3 MB 1.3 MB/s eta 0:00:02
#      --------- ------------------------------ 0.8/3.3 MB 1.2 MB/s eta 0:00:03
#      ---------- ----------------------------- 0.9/3.3 MB 1.3 MB/s eta 0:00:02
#      ------------ --------------------------- 1.0/3.3 MB 1.4 MB/s eta 0:00:02
#      ------------ --------------------------- 1.0/3.3 MB 1.4 MB/s eta 0:00:02
#      ------------ --------------------------- 1.0/3.3 MB 1.4 MB/s eta 0:00:02
#      ------------- -------------------------- 1.1/3.3 MB 1.3 MB/s eta 0:00:02
#      -------------- ------------------------- 1.2/3.3 MB 1.3 MB/s eta 0:00:02
#      ---------------- ----------------------- 1.3/3.3 MB 1.4 MB/s eta 0:00:02
#      ---------------- ----------------------- 1.4/3.3 MB 1.4 MB/s eta 0:00:02
#      ------------------ --------------------- 1.5/3.3 MB 1.4 MB/s eta 0:00:02
#      ------------------- -------------------- 1.6/3.3 MB 1.4 MB/s eta 0:00:02
#      --------------------- ------------------ 1.7/3.3 MB 1.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 1.9/3.3 MB 1.5 MB/s eta 0:00:01
#      ------------------------ --------------- 2.0/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 1.6 MB/s eta 0:00:01
#      -------------------------- ------------- 2.2/3.3 MB 1.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 2.4/3.3 MB 1.3 MB/s eta 0:00:01
#      -------------------------------- ------- 2.7/3.3 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.9/3.3 MB 1.5 MB/s eta 0:00:01
#      -------------------------------------- - 3.1/3.3 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  3.3/3.3 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 3.3/3.3 MB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pandas==1.4.2 (from pysus)
#   Obtaining dependency information for pandas==1.4.2 from https://files.pythonhosted.org/packages/9b/93/e937ef7dc2d712820e4aafdc152d575979adbd192b0ad80f78a28e1f56f3/pandas-1.4.2-cp38-cp38-win_amd64.whl.metadata
#   Downloading pandas-1.4.2-cp38-cp38-win_amd64.whl.metadata (12 kB)
# Collecting pandasql==0.7.3 (from pysus)
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cffi>=1.0.0 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from pysus) (1.16.0)
# Collecting dbfread==2.0.7 (from pysus)
#   Obtaining dependency information for dbfread==2.0.7 from https://files.pythonhosted.org/packages/4c/94/51349e43503e30ed7b4ecfe68a8809cdb58f722c0feb79d18b1f1e36fe74/dbfread-2.0.7-py2.py3-none-any.whl.metadata
#   Downloading dbfread-2.0.7-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting scipy (from pysus)
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/32/8e/7f403535ddf826348c9b8417791e28712019962f7e90ff845896d6325d09/scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
#      ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#      ---------------------------------------- 59.0/59.0 kB 3.0 MB/s eta 0:00:00
# Collecting requests==2.27.1 (from pysus)
#   Obtaining dependency information for requests==2.27.1 from https://files.pythonhosted.org/packages/2d/61/08076519c80041bc0ffa1a8af0cbd3bf3e2b62af10435d269a9d0f40564d/requests-2.27.1-py2.py3-none-any.whl.metadata
#   Downloading requests-2.27.1-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting fastparquet==0.8.1 (from pysus)
#   Obtaining dependency information for fastparquet==0.8.1 from https://files.pythonhosted.org/packages/2d/a7/6696d1445f41a27a211561d1260a1d4ca51effd01a9813d056cd9d61a809/fastparquet-0.8.1-cp38-cp38-win_amd64.whl.metadata
#   Downloading fastparquet-0.8.1-cp38-cp38-win_amd64.whl.metadata (4.1 kB)
# Collecting dask (from pysus)
#   Obtaining dependency information for dask from https://files.pythonhosted.org/packages/07/93/32d3e317fec6d0fc130284f922ad9bd13d9ae0d52245e6ff6e57647e924c/dask-2023.5.0-py3-none-any.whl.metadata
#   Downloading dask-2023.5.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting wget==3.2 (from pysus)
#   Using cached wget-3.2-py3-none-any.whl
# Collecting elasticsearch==7.16.2 (from pysus)
#   Obtaining dependency information for elasticsearch==7.16.2 from https://files.pythonhosted.org/packages/5b/71/9d61ea6bd10e51c8c42fa87f75489c2812e8346875facd0b30a511f0f790/elasticsearch-7.16.2-py2.py3-none-any.whl.metadata
#   Downloading elasticsearch-7.16.2-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting pyarrow==7.0.0 (from pysus)
#   Obtaining dependency information for pyarrow==7.0.0 from https://files.pythonhosted.org/packages/3b/c9/f2eeb63a8057a66d37b35c8db8014585ced62af598b533617ffca780df6a/pyarrow-7.0.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading pyarrow-7.0.0-cp38-cp38-win_amd64.whl.metadata (2.9 kB)
# Collecting tqdm==4.64.0 (from pysus)
#   Obtaining dependency information for tqdm==4.64.0 from https://files.pythonhosted.org/packages/8a/c4/d15f1e627fff25443ded77ea70a7b5532d6371498f9285d44d62587e209c/tqdm-4.64.0-py2.py3-none-any.whl.metadata
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.3 kB ? eta -:--:--
#      ---------------------------------------- 57.3/57.3 kB ? eta 0:00:00
# Collecting urllib3<2,>=1.21.1 (from elasticsearch==7.16.2->pysus)
#   Obtaining dependency information for urllib3<2,>=1.21.1 from https://files.pythonhosted.org/packages/b0/53/aa91e163dcfd1e5b82d8a890ecf13314e3e149c05270cc644581f77f17fd/urllib3-1.26.18-py2.py3-none-any.whl.metadata
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.9 kB ? eta -:--:--
#      ---------------------------------------- 48.9/48.9 kB ? eta 0:00:00
# Requirement already satisfied: certifi in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from elasticsearch==7.16.2->pysus) (2023.7.22)
# Requirement already satisfied: numpy>=1.18 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from fastparquet==0.8.1->pysus) (1.24.4)
# Collecting cramjam>=2.3.0 (from fastparquet==0.8.1->pysus)
#   Obtaining dependency information for cramjam>=2.3.0 from https://files.pythonhosted.org/packages/16/f6/e230eb1121ac44fd26d339fb68ca39cd24a00e0382f7a7db623423407bc6/cramjam-2.8.3-cp38-none-win_amd64.whl.metadata
#   Downloading cramjam-2.8.3-cp38-none-win_amd64.whl.metadata (4.3 kB)
# Collecting fsspec (from fastparquet==0.8.1->pysus)
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/93/6d/66d48b03460768f523da62a57a7e14e5e95fdf339d79e996ce3cecda2cdb/fsspec-2024.3.1-py3-none-any.whl.metadata
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from pandas==1.4.2->pysus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from pandas==1.4.2->pysus) (2023.3.post1)
# Collecting sqlalchemy (from pandasql==0.7.3->pysus)
#   Obtaining dependency information for sqlalchemy from https://files.pythonhosted.org/packages/26/cf/d1a63a928ed699a6f9b8bb8543ecb9a84482652b437b9441ed3a900adec6/SQLAlchemy-2.0.29-cp38-cp38-win_amd64.whl.metadata
#   Downloading SQLAlchemy-2.0.29-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
# Collecting charset-normalizer~=2.0.0 (from requests==2.27.1->pysus)
#   Obtaining dependency information for charset-normalizer~=2.0.0 from https://files.pythonhosted.org/packages/06/b3/24afc8868eba069a7f03650ac750a778862dc34941a4bebeb58706715726/charset_normalizer-2.0.12-py3-none-any.whl.metadata
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from requests==2.27.1->pysus) (3.4)
# Requirement already satisfied: colorama in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from tqdm==4.64.0->pysus) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from cffi>=1.0.0->pysus) (2.21)
# Collecting click>=8.0 (from dask->pysus)
#   Obtaining dependency information for click>=8.0 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle>=1.5.0 (from dask->pysus)
#   Obtaining dependency information for cloudpickle>=1.5.0 from https://files.pythonhosted.org/packages/96/43/dae06432d0c4b1dc9e9149ad37b4ca8384cf6eb7700cd9215b177b914f0a/cloudpickle-3.0.0-py3-none-any.whl.metadata
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from dask->pysus) (23.1)
# Collecting partd>=1.2.0 (from dask->pysus)
#   Obtaining dependency information for partd>=1.2.0 from https://files.pythonhosted.org/packages/11/8a/b7a58e208b144a7315208a0dd627e23f5f50b47fa89c2924bb2e9238ecfb/partd-1.4.1-py3-none-any.whl.metadata
#   Downloading partd-1.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyyaml>=5.3.1 (from dask->pysus)
#   Obtaining dependency information for pyyaml>=5.3.1 from https://files.pythonhosted.org/packages/29/0f/9782fa5b10152abf033aec56a601177ead85ee03b57781f2d9fced09eefc/PyYAML-6.0.1-cp38-cp38-win_amd64.whl.metadata
#   Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
# Collecting toolz>=0.10.0 (from dask->pysus)
#   Obtaining dependency information for toolz>=0.10.0 from https://files.pythonhosted.org/packages/b7/8a/d82202c9f89eab30f9fc05380daae87d617e2ad11571ab23d7c13a29bb54/toolz-0.12.1-py3-none-any.whl.metadata
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from dask->pysus) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from importlib-metadata>=4.13.0->dask->pysus) (3.11.0)
# Collecting locket (from partd>=1.2.0->dask->pysus)
#   Obtaining dependency information for locket from https://files.pythonhosted.org/packages/db/bc/83e112abc66cd466c6b83f99118035867cecd41802f8d044638aa78a106e/locket-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from python-dateutil>=2.8.1->pandas==1.4.2->pysus) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\pc\miniconda3\envs\selenium\lib\site-packages (from sqlalchemy->pandasql==0.7.3->pysus) (4.7.1)
# Collecting greenlet!=0.4.17 (from sqlalchemy->pandasql==0.7.3->pysus)
#   Obtaining dependency information for greenlet!=0.4.17 from https://files.pythonhosted.org/packages/1c/fa/bd5ee0772c7bbcb99bbacdb5608895052349b0ab9f20962c0c81bf6bd41d/greenlet-3.0.3-cp38-cp38-win_amd64.whl.metadata
#   Downloading greenlet-3.0.3-cp38-cp38-win_amd64.whl.metadata (3.9 kB)
# Downloading dbfread-2.0.7-py2.py3-none-any.whl (20 kB)
# Downloading elasticsearch-7.16.2-py2.py3-none-any.whl (385 kB)
#    ---------------------------------------- 0.0/385.7 kB ? eta -:--:--
#    ------------------ --------------------- 174.1/385.7 kB 5.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 337.9/385.7 kB 5.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 337.9/385.7 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 385.7/385.7 kB 2.2 MB/s eta 0:00:00
# Downloading fastparquet-0.8.1-cp38-cp38-win_amd64.whl (617 kB)
#    ---------------------------------------- 0.0/617.8 kB ? eta -:--:--
#    ------------------------- ------------- 399.4/617.8 kB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 617.8/617.8 kB 6.5 MB/s eta 0:00:00
# Downloading pandas-1.4.2-cp38-cp38-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.6 MB 5.2 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/10.6 MB 3.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/10.6 MB 4.6 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/10.6 MB 4.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/10.6 MB 4.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/10.6 MB 5.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/10.6 MB 5.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/10.6 MB 5.5 MB/s eta 0:00:02
#    --------- ------------------------------ 2.5/10.6 MB 5.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/10.6 MB 5.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/10.6 MB 6.1 MB/s eta 0:00:02
#    ------------- -------------------------- 3.6/10.6 MB 5.8 MB/s eta 0:00:02
#    --------------- ------------------------ 4.0/10.6 MB 6.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.6 MB 6.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.6/10.6 MB 6.1 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.6 MB 6.0 MB/s eta 0:00:01
#    ------------------- -------------------- 5.3/10.6 MB 5.9 MB/s eta 0:00:01
#    --------------------- ------------------ 5.8/10.6 MB 6.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.3/10.6 MB 6.5 MB/s eta 0:00:01
#    ------------------------- -------------- 6.8/10.6 MB 6.5 MB/s eta 0:00:01
#    --------------------------- ------------ 7.2/10.6 MB 6.6 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.6 MB 6.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.7/10.6 MB 6.5 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.6 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.4/10.6 MB 6.6 MB/s eta 0:00:01
#    ------------------------------- -------- 8.4/10.6 MB 6.6 MB/s eta 0:00:01
#    ------------------------------- -------- 8.4/10.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.6 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 6.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 6.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 6.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 6.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 9.8/10.6 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.2/10.6 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 5.2 MB/s eta 0:00:00
# Downloading pyarrow-7.0.0-cp38-cp38-win_amd64.whl (16.1 MB)
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#     --------------------------------------- 0.4/16.1 MB 7.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.7/16.1 MB 7.7 MB/s eta 0:00:02
#    - -------------------------------------- 0.7/16.1 MB 5.3 MB/s eta 0:00:03
#    -- ------------------------------------- 1.0/16.1 MB 5.3 MB/s eta 0:00:03
#    --- ------------------------------------ 1.5/16.1 MB 6.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.8/16.1 MB 6.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.9/16.1 MB 5.6 MB/s eta 0:00:03
#    ------ --------------------------------- 2.5/16.1 MB 6.3 MB/s eta 0:00:03
#    ------- -------------------------------- 2.8/16.1 MB 6.4 MB/s eta 0:00:03
#    ------- -------------------------------- 3.1/16.1 MB 6.7 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/16.1 MB 6.7 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/16.1 MB 6.7 MB/s eta 0:00:02
#    -------- ------------------------------- 3.4/16.1 MB 5.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.0/16.1 MB 5.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.0/16.1 MB 5.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.5/16.1 MB 5.7 MB/s eta 0:00:03
#    ------------ --------------------------- 5.0/16.1 MB 6.0 MB/s eta 0:00:02
#    ------------ --------------------------- 5.2/16.1 MB 5.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/16.1 MB 5.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/16.1 MB 5.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/16.1 MB 5.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/16.1 MB 5.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/16.1 MB 5.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/16.1 MB 5.8 MB/s eta 0:00:02
#    -------------- ------------------------- 5.7/16.1 MB 4.5 MB/s eta 0:00:03
#    --------------- ------------------------ 6.2/16.1 MB 4.7 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/16.1 MB 4.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.8/16.1 MB 4.9 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/16.1 MB 5.1 MB/s eta 0:00:02
#    ------------------ --------------------- 7.4/16.1 MB 5.0 MB/s eta 0:00:02
#    ------------------- -------------------- 8.0/16.1 MB 5.2 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.1 MB 5.3 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.1 MB 5.3 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.1 MB 5.3 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.1 MB 4.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.9/16.1 MB 4.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.1 MB 5.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.1 MB 5.1 MB/s eta 0:00:02
#    ------------------------ --------------- 10.0/16.1 MB 5.2 MB/s eta 0:00:02
#    ------------------------- -------------- 10.1/16.1 MB 5.2 MB/s eta 0:00:02
#    ------------------------- -------------- 10.1/16.1 MB 5.2 MB/s eta 0:00:02
#    ------------------------- -------------- 10.3/16.1 MB 5.0 MB/s eta 0:00:02
#    --------------------------- ------------ 11.0/16.1 MB 5.1 MB/s eta 0:00:01
#    --------------------------- ------------ 11.2/16.1 MB 5.2 MB/s eta 0:00:01
#    --------------------------- ------------ 11.2/16.1 MB 5.2 MB/s eta 0:00:01
#    --------------------------- ------------ 11.2/16.1 MB 4.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.4/16.1 MB 4.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.0/16.1 MB 4.8 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/16.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/16.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/16.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/16.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/16.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/16.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/16.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.8/16.1 MB 4.3 MB/s eta 0:00:01
#    --------------------------------- ------ 13.3/16.1 MB 4.3 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.1 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.1 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.1 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.1 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.8/16.1 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 14.5/16.1 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 14.7/16.1 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/16.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  15.7/16.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  16.1/16.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 16.1/16.1 MB 4.6 MB/s eta 0:00:00
# Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.4 kB ? eta -:--:--
#    ---------------------------------------- 78.4/78.4 kB ? eta 0:00:00
# Downloading dask-2023.5.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.2 MB 9.9 MB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.2 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 10.7 MB/s eta 0:00:00
# Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading cramjam-2.8.3-cp38-none-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.6 MB 15.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.7/1.6 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.6 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.6 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.5 MB/s eta 0:00:00
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#    ---------------------------------------- 0.0/172.0 kB ? eta -:--:--
#    --------------------------------------- 172.0/172.0 kB 10.8 MB/s eta 0:00:00
# Downloading partd-1.4.1-py3-none-any.whl (18 kB)
# Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl (157 kB)
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.8 kB ? eta -:--:--
#    ---------------------------------------- 143.8/143.8 kB 8.3 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.29-cp38-cp38-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 16.8 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.1 MB 14.0 MB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 11.1 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp38-cp38-win_amd64.whl (290 kB)
#    ---------------------------------------- 0.0/290.8 kB ? eta -:--:--
#    --------------------------------------- 290.8/290.8 kB 18.7 MB/s eta 0:00:00
# Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Building wheels for collected packages: pysus, pandasql
#   Building wheel for pysus (setup.py): started
#   Building wheel for pysus (setup.py): finished with status 'error'
#   Running setup.py clean for pysus
#   Building wheel for pandasql (setup.py): started
#   Building wheel for pandasql (setup.py): finished with status 'done'
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26798 sha256=68197b009d182dc776f973b8ec4c4f64c1c6ddd605dfe7a37567af22c175c1db
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\ed\8f\46\a383923333728744f01ba24adbd8e364f2cb9470a8b8e5b9ff
# Successfully built pandasql
# Failed to build pysus
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [182 lines of output]
#       C:\Users\PC\miniconda3\envs\selenium\lib\site-packages\setuptools\__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-38
#       creating build\lib.win-amd64-cpython-38\pysus
#       copying pysus\__init__.py -> build\lib.win-amd64-cpython-38\pysus
#       creating build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\CIHA.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\CNES.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\ESUS.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\IBGE.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\PNI.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\SIA.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\SIH.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\SIM.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\SINAN.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\sinasc.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\vaccine.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       copying pysus\online_data\__init__.py -> build\lib.win-amd64-cpython-38\pysus\online_data
#       creating build\lib.win-amd64-cpython-38\pysus\preprocessing
#       copying pysus\preprocessing\decoders.py -> build\lib.win-amd64-cpython-38\pysus\preprocessing
#       copying pysus\preprocessing\ESUS.py -> build\lib.win-amd64-cpython-38\pysus\preprocessing
#       copying pysus\preprocessing\geodata.py -> build\lib.win-amd64-cpython-38\pysus\preprocessing
#       copying pysus\preprocessing\SIM.py -> build\lib.win-amd64-cpython-38\pysus\preprocessing
#       copying pysus\preprocessing\sinan.py -> build\lib.win-amd64-cpython-38\pysus\preprocessing
#       copying pysus\preprocessing\__init__.py -> build\lib.win-amd64-cpython-38\pysus\preprocessing
#       creating build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_cnes.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_decoders.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_esus.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_ibge.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_SIA.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_sih.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_sim.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_sinan.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\test_utilities.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       copying pysus\tests\__init__.py -> build\lib.win-amd64-cpython-38\pysus\tests
#       creating build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\test_ciha.py -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\test_PNI.py -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\test_sia.py -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\test_sih.py -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\test_sim.py -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\test_sinasc.py -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\test_vaccine.py -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\__init__.py -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       running egg_info
#       writing PySUS.egg-info\PKG-INFO
#       writing dependency_links to PySUS.egg-info\dependency_links.txt
#       writing requirements to PySUS.egg-info\requires.txt
#       writing top-level names to PySUS.egg-info\top_level.txt
#       reading manifest file 'PySUS.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       writing manifest file 'PySUS.egg-info\SOURCES.txt'
#       C:\Users\PC\miniconda3\envs\selenium\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'pysus.utilities' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'pysus.utilities' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'pysus.utilities' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'pysus.utilities' to be distributed and are
#               already explicitly excluding 'pysus.utilities' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\PC\miniconda3\envs\selenium\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'pysus.Notebooks' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'pysus.Notebooks' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'pysus.Notebooks' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'pysus.Notebooks' to be distributed and are
#               already explicitly excluding 'pysus.Notebooks' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       creating build\lib.win-amd64-cpython-38\pysus\utilities
#       creating build\lib.win-amd64-cpython-38\pysus\utilities\c-src
#       copying pysus\utilities\c-src\blast.c -> build\lib.win-amd64-cpython-38\pysus\utilities\c-src
#       creating build\lib.win-amd64-cpython-38\pysus\Notebooks
#       copying pysus\Notebooks\Analyzing SIH.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks
#       copying pysus\Notebooks\Analyzing SIM.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks
#       copying pysus\Notebooks\Analyzing SINASC Data.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks
#       copying pysus\Notebooks\Getting_CNES_Data.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks
#       copying pysus\Notebooks\Processing SIM with municipality.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks
#       copying pysus\Notebooks\Processing SIM.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks
#       copying pysus\Notebooks\SINAN.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks
#       creating build\lib.win-amd64-cpython-38\pysus\Notebooks\.ipynb_checkpoints
#       copying pysus\Notebooks\.ipynb_checkpoints\Dengue-checkpoint.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks\.ipynb_checkpoints
#       copying pysus\Notebooks\.ipynb_checkpoints\Processing SIM with municipality-checkpoint.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks\.ipynb_checkpoints
#       copying pysus\Notebooks\.ipynb_checkpoints\Processing SIM-checkpoint.ipynb -> build\lib.win-amd64-cpython-38\pysus\Notebooks\.ipynb_checkpoints
#       copying pysus\utilities\.directory -> build\lib.win-amd64-cpython-38\pysus\utilities
#       copying pysus\utilities\_build_readdbc.py -> build\lib.win-amd64-cpython-38\pysus\utilities
#       copying pysus\utilities\_readdbc.c -> build\lib.win-amd64-cpython-38\pysus\utilities
#       copying pysus\utilities\_readdbc.o -> build\lib.win-amd64-cpython-38\pysus\utilities
#       copying pysus\utilities\_readdbc.so -> build\lib.win-amd64-cpython-38\pysus\utilities
#       copying pysus\utilities\blast.c -> build\lib.win-amd64-cpython-38\pysus\utilities
#       copying pysus\utilities\blast.h -> build\lib.win-amd64-cpython-38\pysus\utilities
#       copying pysus\utilities\readdbc.py -> build\lib.win-amd64-cpython-38\pysus\utilities
#       copying pysus\utilities\c-src\__init__.py -> build\lib.win-amd64-cpython-38\pysus\utilities\c-src
#       copying pysus\utilities\c-src\blast.h -> build\lib.win-amd64-cpython-38\pysus\utilities\c-src
#       copying pysus\utilities\c-src\dbc2dbf.c -> build\lib.win-amd64-cpython-38\pysus\utilities\c-src
#       copying pysus\tests\test_data\EPR-2016-06-01-2016.dbf -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\chik.pickle -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       copying pysus\tests\test_data\sids.dbc -> build\lib.win-amd64-cpython-38\pysus\tests\test_data
#       running build_ext
#       generating cffi module 'build\\temp.win-amd64-cpython-38\\Release\\_readdbc.c'
#       creating build\temp.win-amd64-cpython-38
#       creating build\temp.win-amd64-cpython-38\Release
#       building '_readdbc' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pysus
# ERROR: Could not build wheels for pysus, which is required to install pyproject.toml-based projects

# %%
from pysus.ftp.databases.sinasc import SINASC
sinasc = SINASC().load() # Loads the files from DATASUS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pysus.ftp.databases.sinasc import SINASC
#       2 sinasc = SINASC().load()
#
# ModuleNotFoundError: No module named 'pysus'
